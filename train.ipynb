# %%
train_schedule = []
#k=1
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":1,
                       "top_k":1,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E1K1-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":2,
                       "top_k":1,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E2K1-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":4,
                       "top_k":1,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E4K1-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":8,
                       "top_k":1,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E8K1-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
#k=2
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":2,
                       "top_k":2,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E2K2-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":4,
                       "top_k":2,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E4K2-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":6,
                       "top_k":2,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E6K2-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
train_schedule.append({"data_start":0,
                       "data_end":299,
                       "test_start":0,
                       "test_end":49,
                       "num_experts":8,
                       "top_k":2,
                       "optimizer":'Adam',
                       "loss":'mssiml1',
                       "name":'D300T50-E8K2-Adam-mssiml1-X2-5E-Trial1',
                       "epochs":5,
                       "scale":2,
                       "behavior":'all'})
